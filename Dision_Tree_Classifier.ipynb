# %%
#import libraries
import pandas as pd
df = pd.read_csv("employee-salary-data-1.csv")
df.head()
# Out:
#    SalaryDataID  CalendarYear        EmployeeName               Department  \
# 0             1          2008     Lampkin, Joseph  Louisville Metro Police
# 1             2          2008        Brink, Robin  Louisville Metro Police
# 2             3          2008  Hightower, Timothy  Louisville Metro Police
# 3             4          2008        Kiefer, John  Louisville Metro Police
# 4             5          2008       Banta, Robert  Louisville Metro Police
#
#                          JobTitle  AnnualRate  RegularRate  OvertimeRate  \
# 0  Police Officer                     45219.2     45140.80        655.26
# 1  Police Officer                     49504.0     24060.21        559.00
# 2  Police Officer                     53435.2     53817.28       2045.97
# 3  Police Officer                     51417.6     49216.00          0.00
# 4  Police Officer                     46051.2     46321.36       2225.55
#
#    IncentiveAllowance    Other  YearToDate
# ...

# %%
df.tail()
# Out:
#        SalaryDataID  CalendarYear           EmployeeName  \
# 86695         86696          2015         Hardin, Ashley
# 86696         86697          2016     Goldsmith, Charles
# 86697         86698          2016  Readus-Wright, Mache'
# 86698         86699          2016          Selmon, Bobbi
# 86699         86700          2016          Parrish, Kent
#
#                        Department                        JobTitle  AnnualRate  \
# 86695                     Library  Personnel Specialist               33280.0
# 86696          Parks & Recreation  Park Aide                          31200.0
# 86697                Public Works  Engineer III                       87443.2
# 86698  Human Relations Commission  Compliance Analyst                 37086.4
# 86699             Louisville Fire  Fire Prevention Inspector I        52873.6
#
#        RegularRate  OvertimeRate  IncentiveAllowance    Other  YearToDate
# 86695      1280.00          2.40                 0.0     0.00     1282.40
# ...

# %%
df["Department"] = df["Department"].replace("Louisville Metro Police", 1)

# %%
# machine learning algorithm
from sklearn.tree import DecisionTreeClassifier

#creat and fit our model
model = DecisionTreeClassifier().Fit(X,y)

# predicition
model.predict([[]])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\Quantum\OneDrive\Desktop\Machine_Learning\Dision_Tree_Classifier.ipynb Cell 4' in <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/Quantum/OneDrive/Desktop/Machine_Learning/Dision_Tree_Classifier.ipynb#ch0000003?line=1'>2</a> from sklearn.tree import DecisionTreeClassifier
#       <a href='vscode-notebook-cell:/c%3A/Users/Quantum/OneDrive/Desktop/Machine_Learning/Dision_Tree_Classifier.ipynb#ch0000003?line=3'>4</a> #creat and fit our model
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Quantum/OneDrive/Desktop/Machine_Learning/Dision_Tree_Classifier.ipynb#ch0000003?line=4'>5</a> model = DecisionTreeClassifier().Fit(X,y)
#       <a href='vscode-notebook-cell:/c%3A/Users/Quantum/OneDrive/Desktop/Machine_Learning/Dision_Tree_Classifier.ipynb#ch0000003?line=6'>7</a> # predicition
# ...

# %%
# i have to change the data set for partuculair problm

# how to measure the accuarcy of our model

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

X_train, X_TEST, y_train, y_test = train_test_split(X, y, test_size=0.2) #80% traing data and 20% test data

#creat a model 
model = DecisionTreeClassifier()
#fitting a model 
model.fit(X_train, y_train)

predict_values = model.predict(X_test)
predicted_values

# checking score
#y_test = actual_values


score = accuracy_score(actual_values, predicted_values)
score
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Quantum\OneDrive\Desktop\Machine_Learning\Dision_Tree_Classifier.ipynb Cell 5' in <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/Quantum/OneDrive/Desktop/Machine_Learning/Dision_Tree_Classifier.ipynb#ch0000004?line=4'>5</a> from sklearn.model_selection import train_test_split
#       <a href='vscode-notebook-cell:/c%3A/Users/Quantum/OneDrive/Desktop/Machine_Learning/Dision_Tree_Classifier.ipynb#ch0000004?line=5'>6</a> from sklearn.metrics import accuracy_score
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Quantum/OneDrive/Desktop/Machine_Learning/Dision_Tree_Classifier.ipynb#ch0000004?line=7'>8</a> X_train, X_TEST, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1) #80% traing data and 20% test data
# ...

# %%
# how to train and save your model

import pandas as pd 
import sklearn.tree import DecisionTreeClassifier
import joblib

model = DecisionTreeClassifier().fit(X,y)

joblib.dump(model, "foodie.joblib")

# %%
#how to import/run a stored or saved model on our data

# %%
# graphs 
model = DecisionTreeClassifier().fit(X, y)

#graphic evalution/ look into what happend 
tree.export_graphviz(model
                     out_file ="foodies.dot",
                     feature_names=['Department', 'JobTitle'],
                     class_names =sorted(y.unique()),
                     label='áll',
                     rounded=True,
                     filled=True)
# Out:
#   Input In [8]
#     out_file ="foodies.dot",
#     ^
# SyntaxError: invalid syntax
